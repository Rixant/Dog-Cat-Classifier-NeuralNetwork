# %%
#import relevant libraries
import numpy as np
import pandas as pd
import random as random
import os
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D
from keras.layers import AveragePooling2D, MaxPooling2D, Dropout, GlobalMaxPooling2D, GlobalAveragePooling2D
from keras.models import Model


print('Libraries imported succesfully')
# Out:
# Libraries imported succesfully

# %%
train_images = []
category= []
for dirname, _, filenames in os.walk('./datasets/training_set'):
    print(_[1])
#     for filename in filenames:
        
#         if(filename=='dogs'):
#             category.append('dog')
#         if(filename == 'cats'):
#             category.append('cat')
#         train_images.append(os.path.join(dirname, filename))
# print(category)        
# df={'filename': train_images,'category':category}
# df=pd.DataFrame(df)
# Out:
#   File "<ipython-input-70-d256975c5dd8>", line 14
#     # df=pd.DataFrame(df)
#                                  ^
# SyntaxError: unexpected EOF while parsing

# %%
train_images = import_dataset()
random.shuffle(train_images)
print(train_images)
# Out:
# ['./datasets/training_set/cats/cat.3190.jpg', './datasets/training_set/cats/cat.1521.jpg', './datasets/training_set/dogs/dog.3620.jpg', './datasets/training_set/dogs/dog.2528.jpg', './datasets/training_set/cats/cat.1416.jpg', './datasets/training_set/dogs/dog.1314.jpg', './datasets/training_set/dogs/dog.3592.jpg', './datasets/training_set/cats/cat.1259.jpg', './datasets/training_set/cats/cat.426.jpg', './datasets/training_set/dogs/dog.1806.jpg', './datasets/training_set/cats/cat.1310.jpg', './datasets/training_set/cats/cat.3547.jpg', './datasets/training_set/cats/cat.302.jpg', './datasets/training_set/cats/cat.2295.jpg', './datasets/training_set/cats/cat.564.jpg', './datasets/training_set/dogs/dog.3547.jpg', './datasets/training_set/dogs/dog.688.jpg', './datasets/training_set/cats/cat.3889.jpg', './datasets/training_set/dogs/dog.3613.jpg', './datasets/training_set/dogs/dog.353.jpg', './datasets/training_set/cats/cat.1027.jpg', './datasets/training_set/cats/cat.2865.jpg', './datasets/
# ...

# %%
def model():
    model = K.Sequential()
    model.add(Conv2D(32 , 3, 3,  input_shape = (64, 64, 3), activation = 'relu'))
    model.add(MaxPooling2D(pool_size  = (2,2)))
    model.add(Flatten())
    model.add(Dense(128, activation = 'relu'))
    model.add(Dense(1, activation = 'sigmoid'))
  
    return model

# %%
model = model()

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255, 
                               shear_range = 0.2,
                               zoom_range = 0.2,
                               horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

train_set = train_datagen.flow_from_directory('./datasets/training_set', target_size = (64,64), 
                                             batch_size = 32, 
                                             class_mode = 'binary')


test_set = test_datagen.flow_from_directory('./datasets/test_set', target_size = (64,64), 
                                             batch_size = 32, 
                                             class_mode = 'binary')
# Out:
# Found 8005 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.

# %%
model.fit_generator(train_set, steps_per_epoch = 100, 
                        epochs = 10, 
                        validation_data = test_set, 
                        validation_steps = 50)
# Out:
# Epoch 1/10
# 100/100 [==============================] - 11s 110ms/step - loss: 0.7020 - accuracy: 0.5375 - val_loss: 0.6495 - val_accuracy: 0.6413
# Epoch 2/10
# 100/100 [==============================] - 11s 113ms/step - loss: 0.6434 - accuracy: 0.6362 - val_loss: 0.6130 - val_accuracy: 0.6744
# Epoch 3/10
# 100/100 [==============================] - 11s 106ms/step - loss: 0.6132 - accuracy: 0.6622 - val_loss: 0.6019 - val_accuracy: 0.6913
# Epoch 4/10
# 100/100 [==============================] - 10s 103ms/step - loss: 0.6034 - accuracy: 0.6829 - val_loss: 0.5942 - val_accuracy: 0.6950
# Epoch 5/10
# 100/100 [==============================] - 10s 101ms/step - loss: 0.5851 - accuracy: 0.6866 - val_loss: 0.5901 - val_accuracy: 0.6931
# Epoch 6/10
# 100/100 [==============================] - 11s 106ms/step - loss: 0.5877 - accuracy: 0.6802 - val_loss: 0.5769 - val_accuracy: 0.6919
# Epoch 7/10
# ...
